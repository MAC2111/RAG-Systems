# %%
# !pip install qdrant_client langchain_huggingface langchain_community langchain-qdrant pypdf openai langchain    , new

# %%
from qdrant_client import QdrantClient
from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_qdrant import QdrantVectorStore
import openai
import os

# %%
embed_model=HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-large-instruct')

# %%
pages[45]
# Out:
# Document(metadata={'producer': 'OpenOffice 4.0.1', 'creator': 'Writer', 'creationdate': '2017-02-04T17:05:23+10:00', 'author': 'GEM', 'source': '/content/power-subconscious-mind_copy.pdf', 'total_pages': 171, 'page': 45, 'page_label': '46'}, page_content="sus was actually appealing to the cooperation of the subconscious mind of\nthe blind men. Their faith was their great expectancy, their inner feeling, \ntheir inner conviction that something miraculous would happen, and that \ntheir prayer would be answered, and it was. This is the time-honored \ntechnique of healing, utilized alike by all healing groups throughout the \nworld regardless of religious affiliation.\nIn the words, see that no man know it, Jesus enjoins the newly healed \npatients not to discuss their healing because they might be subjected to \nthe skeptical and derogatory criticisms of the unbelieving. This might tend\nto undo the benefits they had received at the hand of Jesus by depositing \nthoughts of fear, doubt 
# ...

# %%
len(pages)
# Out:
# 88

# %% [markdown]
# Splitting documents into chunks

# %%
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=2500,
    chunk_overlap=250
)

# %%
#create an empty list to storee processed document chunks
doc_list=[]
#iterate over each page inth ectracted pages
for page in pages:
#splite the page conntent into smaller chunks
  pg_split=text_splitter.split_text(page.page_content)
#iterate over ecah chunks and create document objects
  for pg_sub_split in pg_split:
    #metadata for each chunk, including source and page number
    metadata={"source":"enterpuner", "page_no": page.metadata["page"]+1}
    #create a document object with content and matedata


    doc_string=Document(page_content=pg_sub_split, metadata=metadata)
#append the document object to the list
    doc_list.append(doc_string)

# %%
# this is code of explaniation
# !pip install qdrant_client langchain_huggingface langchain_community langchain-qdrant pypdf openai langchain

from qdrant_client import QdrantClient
from langchain_core.documents import Document
from langchain_document_loaders import PyPDFLoader
from langchain_text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceBgeEmbeddings, HuggingFaceEmbeddings
from langchain_qdrant import QdrantVectorStore
import openai
import os

embed_model = HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-large-instruct')

loaders = PyPDFLoader("/content/power-subconscious-mind_copy.pdf")
pages = loaders.load()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2500,
    chunk_overlap=250
)

doc_list = []
for page in pages:
    pg_split = text_splitter.split_text(page.page_content)
    for pg_sub_split in pg_split:
        metadata = {"source": "enterpuner", "page_no": page.metadata["page"] + 1}
        doc_string = Document(page_content=pg_sub_split, metadata=metadata)
        doc_list.append(doc_string)

qdrant_url = "https://999bba40-8d46-445c-818b-8c6e8d58f2c5.us-west-2-0.aws.cloud.qdrant.io:6333"
qdrant_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.oq6Vn-RUsiTljZvKkecmx6VphNkM2zBMmXxOGlFxtCM"
collections_name = "demo"

qdrant = QdrantVectorStore.from_documents(
    doc_list,
    embed_model,
    url=qdrant_url,
    api_key=qdrant_key,
    collection_name=collections_name
)
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1900621384.py in <cell line: 0>()
#       4 from qdrant_client import QdrantClient
#       5 from langchain_core.documents import Document
# ----> 6 from langchain_document_loaders import PyPDFLoader
#       7 from langchain_text_splitter import RecursiveCharacterTextSplitter
#       8 from langchain.embeddings import HuggingFaceBgeEmbeddings, HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'langchain_document_loaders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
doc_list[20]
# Out:
# Document(metadata={'source': 'enterpuner', 'page_no': 18}, page_content='The Duality Of Mind\nYou have only one mind, but your mind possesses two distinctive charac-\nteristics. The line of demarcation between the two is well known to all \nthinking men and women today. The two functions of your mind are es-\nsentially unlike. Each is endowed with separate and distinct attributes and\npowers. The nomenclature generally used to distinguish the two functions \nof your mind is as follows: The objective and subjective mind, the con-\nscious and subconscious mind, the waking and sleeping mind, the surface \nself and the deep self, the voluntary mind and the involuntary mind, the \nmale and the female and many other terms. You will find the terms “con-\nscious” and “subconscious” used to represent the dual nature of your \nmind throughout this book.\nThe Conscious & Subconscious Minds\nAn excellent way to get acquainted with the two functions of your mind is \nto look upon your own mind as
# ...

# %%
page.page_content
# Out:
# 'ness, faith, meekness and temperance.\n22. You are a child of infinite life which knows no end. You are a child of \neternity. You are wonderful!\nI hope you have enjoyed reading The Power of Your Subconscious Mind by\nDr Joseph Murphy.\nClick for More Free Books by Joseph Murphy.\nFor More Free PDF Books on the Law of Attraction and Metaphysics Visit \nthe Law of Attraction Haven.\nMore Free Books Law of Attraction Haven'

# %%
len(doc_list)
# Out:
# 286

# %%
qdrant_url="https://cae72df7-69c8-43fe-94f5-34fb22d0af1f.europe-west3-0.gcp.cloud.qdrant.io:6333"
qdrant_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.JEzckVGYrOZtDmObjOuJIQtIJ09m1_4RMFlzp4ZvjGE"
collections_name="ddemo"

# %%
#initialize QdranVectoreStore with documents and embedding model
qdrant=QdrantVectorStore.from_documents(
    doc_list,                  #list of document objects to be stored in the vectore store
    embed_model,               #embedding model used to convert documents into vectors
    url=qdrant_url,            #url for the qdrant service
    api_key=qdrant_key,        #api key for accessing the qdrant service
    collection_name=collections_name            #name of the collections to store the vectors in

)

# %%
query="what is impressed in subconsious is expressed"
results=qdrant.similarity_search(query, k=5)

# %%
results[2]
# Out:
# Document(metadata={'source': 'enterpuner', 'page_no': 70, '_id': '692c0411-3462-431c-acee-7470b6942d4f', '_collection_name': 'ddemo'}, page_content='Chapter VII\nThe Tendency of the Subconscious is Lifeward\nOver ninety percent of your mental life is subconscious, so men and wom-\nen who fail to make use of this marvelous power live within very narrow \nlimits. Your subconscious processes are always lifeward and constructive. \nYour subconscious is the builder of your body and maintains all its vital \nfunctions. It is on the job twenty-four hours a day and never sleeps. It is \nalways trying to help and preserve you from harm.\nYour subconscious mind is in touch with infinite life and boundless wis-\ndom, and its impulses and ideas are always lifeward. The great aspira-\ntions, inspirations and visions for a grader and nobler life spring from the \nsubconscious. Your profoundest convictions are those you cannot argue \nabout rationally because they do not come from your conscious mi
# ...

# %%
results[2].page_content
# Out:
# 'Chapter VII\nThe Tendency of the Subconscious is Lifeward\nOver ninety percent of your mental life is subconscious, so men and wom-\nen who fail to make use of this marvelous power live within very narrow \nlimits. Your subconscious processes are always lifeward and constructive. \nYour subconscious is the builder of your body and maintains all its vital \nfunctions. It is on the job twenty-four hours a day and never sleeps. It is \nalways trying to help and preserve you from harm.\nYour subconscious mind is in touch with infinite life and boundless wis-\ndom, and its impulses and ideas are always lifeward. The great aspira-\ntions, inspirations and visions for a grader and nobler life spring from the \nsubconscious. Your profoundest convictions are those you cannot argue \nabout rationally because they do not come from your conscious mind; \nthey come from your subconscious mind. Your subconscious speaks to \nyou in intuitions, impulses, hunches, intimations, urges and ideas, and i
# ...

# %% [markdown]
# MMR MAXIMUM MARGINAL RELEVANCE

# %%
docs_mmr=qdrant.max_marginal_relevance_search(query, k=5)

# %%
docs_mmr[2].page_content
# Out:
# "sus was actually appealing to the cooperation of the subconscious mind of\nthe blind men. Their faith was their great expectancy, their inner feeling, \ntheir inner conviction that something miraculous would happen, and that \ntheir prayer would be answered, and it was. This is the time-honored \ntechnique of healing, utilized alike by all healing groups throughout the \nworld regardless of religious affiliation.\nIn the words, see that no man know it, Jesus enjoins the newly healed \npatients not to discuss their healing because they might be subjected to \nthe skeptical and derogatory criticisms of the unbelieving. This might tend\nto undo the benefits they had received at the hand of Jesus by depositing \nthoughts of fear, doubt and anxiety in the subconscious mind.\n...for with authority and power he commandeth the unclean spirits, and \nthey came out. Luke 4:36.\nWhen the sick came to Jesus to be healed, they were healed by their faith\ntogether with his faith and understanding
# ...

# %% [markdown]
# other types of retrievers which are SVM, TFID

# %%
from langchain.retrievers import SVMRetriever
from langchain.retrievers import TFIDFRetriever

# %%
texts=[doc.page_content for doc in doc_list]
svm_retriever =SVMRetriever.from_texts(texts, embed_model)
tfidf_retriever=TFIDFRetriever.from_texts(texts)

# %%
query="what is impressed in subconsious is expressed"
docs_svm=svm_retriever.get_relevant_documents(query)
docs_svm[2]
# Out:
# Document(metadata={}, page_content='The Terms Objective & Subjective Mind Clarified\nYour conscious mind is sometimes referred to as your objective mind be-\ncause it deals with outward objects. The objective mind takes cognizance \nof the objective world. Its media of observation are your five physical \nsenses. Your objective mind is your guide and director in your contact \nwith your environment. You gain knowledge through your five senses. \nYour objective mind learns thought observation, experience and educa-\ntion. As previously pointed out, the greatest function of the objective \nmind is that of reasoning.\nSuppose you are one of the thousands of tourists who come to Los Ange-\nles annually. You would come to the conclusion that it is a beautiful city \nbased upon your observation of the parks, pretty gardens, majestic build-\nings and lovely homes. This is the working of your objective mind.  \nYour subconscious mind is oftentimes referred to as your subjective mind.\nYour s
# ...

# %%
query="what is impressed in subconsious is expressed"
docs_tfid=tfidf_retriever.get_relevant_documents(query)
docs_tfid[3]
# Out:
# Document(metadata={}, page_content="lowing truth, 'The perfection of God is now being expressed through me. \nThe idea of perfect health is now filling my subconscious mind. The image \nGod has of me is a perfect image, and my subconscious mind recreates \nmy body in perfect accordance with the perfect image held in the mind of \nGod.'” This minister had a remarkable healing. This is a simple, easy way \nof conveying the idea of perfect health to your subconscious mind.\nAnother wonderful way to convey the idea of health to your subconscious \nmind is through disciplined or scientific imagination. I told a man who was\nsuffering from functional paralysis to make a vivid picture of himself walk-\ning around in his office, touching the desk, answering the telephone and \ndoing all the things he ordinarily would do if he were healed. I explained \nto him that this idea and mental picture of perfect health would be ac-\ncepted by his subconscious mind.\nHe lived the role and actually fel
# ...
